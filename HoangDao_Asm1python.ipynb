# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('imports-85.csv')

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration doors  \
# 0            3                 ?  alfa-romero       gas        std   two
# 1            3                 ?  alfa-romero       gas        std   two
# 2            1                 ?  alfa-romero       gas        std   two
# 3            2               164         audi       gas        std  four
# 4            2               164         audi       gas        std  four
# ..         ...               ...          ...       ...        ...   ...
# 200         -1                95        volvo       gas        std  four
# 201         -1                95        volvo       gas      turbo  four
# 202         -1                95        volvo       gas        std  four
# 203         -1                95        volvo    diesel      turbo  four
# 204         -1                95        volvo       gas      turbo  four
#
#             body drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0    convertible          rwd           front        88.6  ...          130
# 1    convertible          rwd           front        88.6  ...          130
# 2      hatchback          rwd           front        94.5  ...          152
# 3          sedan          fwd           front        99.8  ...          109
# 4          sedan          4wd           front        99.4  ...          136
# ..           ...          ...             ...         ...  ...          ...
# 200        sedan          rwd           front       109.1  ...          141
# 201        sedan          rwd           front       109.1  ...          141
# 202        sedan          rwd           front       109.1  ...          173
# 203        sedan          rwd           front       109.1  ...          145
# 204        sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio   hp  peak-rpm city-mpg  \
# 0           mpfi  3.47    2.68               9.0  111      5000       21
# 1           mpfi  3.47    2.68               9.0  111      5000       21
# 2           mpfi  2.68    3.47               9.0  154      5000       19
# 3           mpfi  3.19     3.4              10.0  102      5500       24
# 4           mpfi  3.19     3.4               8.0  115      5500       18
# ..           ...   ...     ...               ...  ...       ...      ...
# 200         mpfi  3.78    3.15               9.5  114      5400       23
# 201         mpfi  3.78    3.15               8.7  160      5300       19
# 202         mpfi  3.58    2.87               8.8  134      5500       18
# 203          idi  3.01     3.4              23.0  106      4800       26
# 204         mpfi  3.78    3.15               9.5  114      5400       19
#
#     hw-mpg  price
# 0       27  13495
# 1       27  16500
# 2       26  16500
# 3       30  13950
# 4       22  17450
# ..     ...    ...
# 200     28  16845
# 201     25  19045
# 202     23  21485
# 203     27  22470
# 204     25  22625
#
# [205 rows x 26 columns]

# %%
df=df.replace("?",np.NaN)

# %%
#Transforming to correct type of data for processing
df['normalized-losses']=df['normalized-losses'].astype(str).astype(float)
df['doors']=df['doors'].astype(str)
df['bore']=df['bore'].astype(str).astype(float)
df['stroke']=df['stroke'].astype(str).astype(float)
df['hp']=df['hp'].astype(str).astype(float)
df['peak-rpm']=df['peak-rpm'].astype(str).astype(float)
df['price']=df['price'].astype(str).astype(float)

# %%
#Observing the mean of continuous attributes
df.mean()
# Out:
# symboling                0.834146
# normalized-losses      122.000000
# wheel-base              98.756585
# length                 174.049268
# width                   65.907805
# height                  53.724878
# curb-weight           2555.565854
# engine-size            126.907317
# bore                     3.329751
# stroke                   3.255423
# compression-ratio       10.142537
# hp                     104.256158
# peak-rpm              5125.369458
# city-mpg                25.219512
# hw-mpg                  30.751220
# price                13207.129353
# dtype: float64

# %%
#Observing the median of continuous attributes
df.median()
# Out:
# symboling                1.00
# normalized-losses      115.00
# wheel-base              97.00
# length                 173.20
# width                   65.50
# height                  54.10
# curb-weight           2414.00
# engine-size            120.00
# bore                     3.31
# stroke                   3.29
# compression-ratio        9.00
# hp                      95.00
# peak-rpm              5200.00
# city-mpg                24.00
# hw-mpg                  30.00
# price                10295.00
# dtype: float64

# %%
#Using mean to fill missing values in normalized-losses, bore,stroke columns
df['normalized-losses'].fillna(value=df['normalized-losses'].mean(), inplace=True)
df['bore'].fillna(value=df['bore'].mean(), inplace=True)
df['stroke'].fillna(value=df['stroke'].mean(), inplace=True)

# %%
#Using median to fill missing values in price, hp, peak-rpm columns
df['price'].fillna(value=df['price'].median(), inplace=True)
df['hp'].fillna(value=df['hp'].median(), inplace=True)
df['peak-rpm'].fillna(value=df['peak-rpm'].median(), inplace=True)

# %%
#Observing attribute doors
df.loc[(df['body']=='sedan') & (df['doors']=='two')]
# Out:
#      symboling  normalized-losses        make fuel-type aspiration doors  \
# 5            2              122.0        audi       gas        std   two
# 10           2              192.0         bmw       gas        std   two
# 12           0              188.0         bmw       gas        std   two
# 16           0              122.0         bmw       gas        std   two
# 42           1              107.0       honda       gas        std   two
# 44           1              122.0       isuzu       gas        std   two
# 49           0              122.0      jaguar       gas        std   two
# 89           1              128.0      nissan       gas        std   two
# 90           1              128.0      nissan    diesel        std   two
# 91           1              128.0      nissan       gas        std   two
# 94           1              128.0      nissan       gas        std   two
# 163          1              168.0      toyota       gas        std   two
# 165          1              168.0      toyota       gas        std   two
# 182          2              122.0  volkswagen    diesel        std   two
# 183          2              122.0  volkswagen       gas        std   two
#
#       body drive-wheels engine-location  wheel-base  ...  engine-size  \
# 5    sedan          fwd           front        99.8  ...          136
# 10   sedan          rwd           front       101.2  ...          108
# 12   sedan          rwd           front       101.2  ...          164
# 16   sedan          rwd           front       103.5  ...          209
# 42   sedan          fwd           front        96.5  ...          110
# 44   sedan          fwd           front        94.5  ...           90
# 49   sedan          rwd           front       102.0  ...          326
# 89   sedan          fwd           front        94.5  ...           97
# 90   sedan          fwd           front        94.5  ...          103
# 91   sedan          fwd           front        94.5  ...           97
# 94   sedan          fwd           front        94.5  ...           97
# 163  sedan          rwd           front        94.5  ...           98
# 165  sedan          rwd           front        94.5  ...           98
# 182  sedan          fwd           front        97.3  ...           97
# 183  sedan          fwd           front        97.3  ...          109
#
#      fuel-system  bore  stroke compression-ratio     hp  peak-rpm city-mpg  \
# 5           mpfi  3.19    3.40               8.5  110.0    5500.0       19
# 10          mpfi  3.50    2.80               8.8  101.0    5800.0       23
# 12          mpfi  3.31    3.19               9.0  121.0    4250.0       21
# 16          mpfi  3.62    3.39               8.0  182.0    5400.0       16
# 42          2bbl  3.15    3.58               9.1  100.0    5500.0       25
# 44          2bbl  3.03    3.11               9.6   70.0    5400.0       38
# 49          mpfi  3.54    2.76              11.5  262.0    5000.0       13
# 89          2bbl  3.15    3.29               9.4   69.0    5200.0       31
# 90           idi  2.99    3.47              21.9   55.0    4800.0       45
# 91          2bbl  3.15    3.29               9.4   69.0    5200.0       31
# 94          2bbl  3.15    3.29               9.4   69.0    5200.0       31
# 163         2bbl  3.19    3.03               9.0   70.0    4800.0       29
# 165         mpfi  3.24    3.08               9.4  112.0    6600.0       26
# 182          idi  3.01    3.40              23.0   52.0    4800.0       37
# 183         mpfi  3.19    3.40               9.0   85.0    5250.0       27
#
#      hw-mpg    price
# 5        25  15250.0
# 10       29  16430.0
# 12       28  20970.0
# 16       22  41315.0
# 42       31  10345.0
# 44       43  10295.0
# 49       17  36000.0
# 89       37   5499.0
# 90       50   7099.0
# 91       37   6649.0
# 94       37   7299.0
# 163      34   8058.0
# 165      29   9298.0
# 182      46   7775.0
# 183      34   7975.0
#
# [15 rows x 26 columns]

# %%
df.loc[(df['body']=='hatchback')&(df['doors']=='two')]
# Out:
#      symboling  normalized-losses         make fuel-type aspiration doors  \
# 2            1              122.0  alfa-romero       gas        std   two
# 9            0              122.0         audi       gas      turbo   two
# 18           2              121.0    chevrolet       gas        std   two
# 19           1               98.0    chevrolet       gas        std   two
# 21           1              118.0        dodge       gas        std   two
# 22           1              118.0        dodge       gas        std   two
# 23           1              118.0        dodge       gas      turbo   two
# 29           3              145.0        dodge       gas      turbo   two
# 30           2              137.0        honda       gas        std   two
# 31           2              137.0        honda       gas        std   two
# 32           1              101.0        honda       gas        std   two
# 33           1              101.0        honda       gas        std   two
# 34           1              101.0        honda       gas        std   two
# 37           0              106.0        honda       gas        std   two
# 38           0              106.0        honda       gas        std   two
# 46           2              122.0        isuzu       gas        std   two
# 50           1              104.0        mazda       gas        std   two
# 51           1              104.0        mazda       gas        std   two
# 52           1              104.0        mazda       gas        std   two
# 55           3              150.0        mazda       gas        std   two
# 56           3              150.0        mazda       gas        std   two
# 57           3              150.0        mazda       gas        std   two
# 58           3              150.0        mazda       gas        std   two
# 59           1              129.0        mazda       gas        std   two
# 61           1              129.0        mazda       gas        std   two
# 75           1              122.0      mercury       gas      turbo   two
# 76           2              161.0   mitsubishi       gas        std   two
# 77           2              161.0   mitsubishi       gas        std   two
# 78           2              161.0   mitsubishi       gas        std   two
# 79           1              161.0   mitsubishi       gas      turbo   two
# 80           3              153.0   mitsubishi       gas      turbo   two
# 81           3              153.0   mitsubishi       gas        std   two
# 82           3              122.0   mitsubishi       gas      turbo   two
# 83           3              122.0   mitsubishi       gas      turbo   two
# 84           3              122.0   mitsubishi       gas      turbo   two
# 95           1              128.0       nissan       gas        std   two
# 104          3              194.0       nissan       gas        std   two
# 105          3              194.0       nissan       gas      turbo   two
# 106          1              231.0       nissan       gas        std   two
# 118          1              119.0     plymouth       gas        std   two
# 119          1              119.0     plymouth       gas      turbo   two
# 124          3              122.0     plymouth       gas      turbo   two
# 125          3              186.0      porsche       gas        std   two
# 129          1              122.0      porsche       gas        std   two
# 131          2              122.0      renault       gas        std   two
# 132          3              150.0         saab       gas        std   two
# 134          3              150.0         saab       gas        std   two
# 136          3              150.0         saab       gas      turbo   two
# 138          2               83.0       subaru       gas        std   two
# 139          2               83.0       subaru       gas        std   two
# 140          2               83.0       subaru       gas        std   two
# 150          1               87.0       toyota       gas        std   two
# 151          1               87.0       toyota       gas        std   two
# 164          1              168.0       toyota       gas        std   two
# 166          1              168.0       toyota       gas        std   two
# 169          2              134.0       toyota       gas        std   two
# 171          2              134.0       toyota       gas        std   two
# 178          3              197.0       toyota       gas        std   two
# 179          3              197.0       toyota       gas        std   two
# 190          3              256.0   volkswagen       gas        std   two
#
#           body drive-wheels engine-location  wheel-base  ...  engine-size  \
# 2    hatchback          rwd           front        94.5  ...          152
# 9    hatchback          4wd           front        99.5  ...          131
# 18   hatchback          fwd           front        88.4  ...           61
# 19   hatchback          fwd           front        94.5  ...           90
# 21   hatchback          fwd           front        93.7  ...           90
# 22   hatchback          fwd           front        93.7  ...           90
# 23   hatchback          fwd           front        93.7  ...           98
# 29   hatchback          fwd           front        95.9  ...          156
# 30   hatchback          fwd           front        86.6  ...           92
# 31   hatchback          fwd           front        86.6  ...           92
# 32   hatchback          fwd           front        93.7  ...           79
# 33   hatchback          fwd           front        93.7  ...           92
# 34   hatchback          fwd           front        93.7  ...           92
# 37   hatchback          fwd           front        96.5  ...          110
# 38   hatchback          fwd           front        96.5  ...          110
# 46   hatchback          rwd           front        96.0  ...          119
# 50   hatchback          fwd           front        93.1  ...           91
# 51   hatchback          fwd           front        93.1  ...           91
# 52   hatchback          fwd           front        93.1  ...           91
# 55   hatchback          rwd           front        95.3  ...           70
# 56   hatchback          rwd           front        95.3  ...           70
# 57   hatchback          rwd           front        95.3  ...           70
# 58   hatchback          rwd           front        95.3  ...           80
# 59   hatchback          fwd           front        98.8  ...          122
# 61   hatchback          fwd           front        98.8  ...          122
# 75   hatchback          rwd           front       102.7  ...          140
# 76   hatchback          fwd           front        93.7  ...           92
# 77   hatchback          fwd           front        93.7  ...           92
# 78   hatchback          fwd           front        93.7  ...           92
# 79   hatchback          fwd           front        93.0  ...           98
# 80   hatchback          fwd           front        96.3  ...          110
# 81   hatchback          fwd           front        96.3  ...          122
# 82   hatchback          fwd           front        95.9  ...          156
# 83   hatchback          fwd           front        95.9  ...          156
# 84   hatchback          fwd           front        95.9  ...          156
# 95   hatchback          fwd           front        94.5  ...           97
# 104  hatchback          rwd           front        91.3  ...          181
# 105  hatchback          rwd           front        91.3  ...          181
# 106  hatchback          rwd           front        99.2  ...          181
# 118  hatchback          fwd           front        93.7  ...           90
# 119  hatchback          fwd           front        93.7  ...           98
# 124  hatchback          rwd           front        95.9  ...          156
# 125  hatchback          rwd           front        94.5  ...          151
# 129  hatchback          rwd           front        98.4  ...          203
# 131  hatchback          fwd           front        96.1  ...          132
# 132  hatchback          fwd           front        99.1  ...          121
# 134  hatchback          fwd           front        99.1  ...          121
# 136  hatchback          fwd           front        99.1  ...          121
# 138  hatchback          fwd           front        93.7  ...           97
# 139  hatchback          fwd           front        93.7  ...          108
# 140  hatchback          4wd           front        93.3  ...          108
# 150  hatchback          fwd           front        95.7  ...           92
# 151  hatchback          fwd           front        95.7  ...           92
# 164  hatchback          rwd           front        94.5  ...           98
# 166  hatchback          rwd           front        94.5  ...           98
# 169  hatchback          rwd           front        98.4  ...          146
# 171  hatchback          rwd           front        98.4  ...          146
# 178  hatchback          rwd           front       102.9  ...          171
# 179  hatchback          rwd           front       102.9  ...          171
# 190  hatchback          fwd           front        94.5  ...          109
#
#      fuel-system      bore    stroke compression-ratio     hp  peak-rpm  \
# 2           mpfi  2.680000  3.470000              9.00  154.0    5000.0
# 9           mpfi  3.130000  3.400000              7.00  160.0    5500.0
# 18          2bbl  2.910000  3.030000              9.50   48.0    5100.0
# 19          2bbl  3.030000  3.110000              9.60   70.0    5400.0
# 21          2bbl  2.970000  3.230000              9.41   68.0    5500.0
# 22          2bbl  2.970000  3.230000              9.40   68.0    5500.0
# 23          mpfi  3.030000  3.390000              7.60  102.0    5500.0
# 29           mfi  3.600000  3.900000              7.00  145.0    5000.0
# 30          1bbl  2.910000  3.410000              9.60   58.0    4800.0
# 31          1bbl  2.910000  3.410000              9.20   76.0    6000.0
# 32          1bbl  2.910000  3.070000             10.10   60.0    5500.0
# 33          1bbl  2.910000  3.410000              9.20   76.0    6000.0
# 34          1bbl  2.910000  3.410000              9.20   76.0    6000.0
# 37          1bbl  3.150000  3.580000              9.00   86.0    5800.0
# 38          1bbl  3.150000  3.580000              9.00   86.0    5800.0
# 46          spfi  3.430000  3.230000              9.20   90.0    5000.0
# 50          2bbl  3.030000  3.150000              9.00   68.0    5000.0
# 51          2bbl  3.030000  3.150000              9.00   68.0    5000.0
# 52          2bbl  3.030000  3.150000              9.00   68.0    5000.0
# 55          4bbl  3.329751  3.255423              9.40  101.0    6000.0
# 56          4bbl  3.329751  3.255423              9.40  101.0    6000.0
# 57          4bbl  3.329751  3.255423              9.40  101.0    6000.0
# 58          mpfi  3.329751  3.255423              9.40  135.0    6000.0
# 59          2bbl  3.390000  3.390000              8.60   84.0    4800.0
# 61          2bbl  3.390000  3.390000              8.60   84.0    4800.0
# 75          mpfi  3.780000  3.120000              8.00  175.0    5000.0
# 76          2bbl  2.970000  3.230000              9.40   68.0    5500.0
# 77          2bbl  2.970000  3.230000              9.40   68.0    5500.0
# 78          2bbl  2.970000  3.230000              9.40   68.0    5500.0
# 79          spdi  3.030000  3.390000              7.60  102.0    5500.0
# 80          spdi  3.170000  3.460000              7.50  116.0    5500.0
# 81          2bbl  3.350000  3.460000              8.50   88.0    5000.0
# 82          spdi  3.580000  3.860000              7.00  145.0    5000.0
# 83          spdi  3.590000  3.860000              7.00  145.0    5000.0
# 84          spdi  3.590000  3.860000              7.00  145.0    5000.0
# 95          2bbl  3.150000  3.290000              9.40   69.0    5200.0
# 104         mpfi  3.430000  3.270000              9.00  160.0    5200.0
# 105         mpfi  3.430000  3.270000              7.80  200.0    5200.0
# 106         mpfi  3.430000  3.270000              9.00  160.0    5200.0
# 118         2bbl  2.970000  3.230000              9.40   68.0    5500.0
# 119         spdi  3.030000  3.390000              7.60  102.0    5500.0
# 124         spdi  3.590000  3.860000              7.00  145.0    5000.0
# 125         mpfi  3.940000  3.110000              9.50  143.0    5500.0
# 129         mpfi  3.940000  3.110000             10.00  288.0    5750.0
# 131         mpfi  3.460000  3.900000              8.70   95.0    5200.0
# 132         mpfi  3.540000  3.070000              9.31  110.0    5250.0
# 134         mpfi  2.540000  2.070000              9.30  110.0    5250.0
# 136         mpfi  3.540000  3.070000              9.00  160.0    5500.0
# 138         2bbl  3.620000  2.360000              9.00   69.0    4900.0
# 139         2bbl  3.620000  2.640000              8.70   73.0    4400.0
# 140         2bbl  3.620000  2.640000              8.70   73.0    4400.0
# 150         2bbl  3.050000  3.030000              9.00   62.0    4800.0
# 151         2bbl  3.050000  3.030000              9.00   62.0    4800.0
# 164         2bbl  3.190000  3.030000              9.00   70.0    4800.0
# 166         mpfi  3.240000  3.080000              9.40  112.0    6600.0
# 169         mpfi  3.620000  3.500000              9.30  116.0    4800.0
# 171         mpfi  3.620000  3.500000              9.30  116.0    4800.0
# 178         mpfi  3.270000  3.350000              9.30  161.0    5200.0
# 179         mpfi  3.270000  3.350000              9.30  161.0    5200.0
# 190         mpfi  3.190000  3.400000              8.50   90.0    5500.0
#
#     city-mpg  hw-mpg    price
# 2         19      26  16500.0
# 9         16      22  10295.0
# 18        47      53   5151.0
# 19        38      43   6295.0
# 21        37      41   5572.0
# 22        31      38   6377.0
# 23        24      30   7957.0
# 29        19      24  12964.0
# 30        49      54   6479.0
# 31        31      38   6855.0
# 32        38      42   5399.0
# 33        30      34   6529.0
# 34        30      34   7129.0
# 37        27      33   7895.0
# 38        27      33   9095.0
# 46        24      29  11048.0
# 50        30      31   5195.0
# 51        31      38   6095.0
# 52        31      38   6795.0
# 55        17      23  10945.0
# 56        17      23  11845.0
# 57        17      23  13645.0
# 58        16      23  15645.0
# 59        26      32   8845.0
# 61        26      32  10595.0
# 75        19      24  16503.0
# 76        37      41   5389.0
# 77        31      38   6189.0
# 78        31      38   6669.0
# 79        24      30   7689.0
# 80        23      30   9959.0
# 81        25      32   8499.0
# 82        19      24  12629.0
# 83        19      24  14869.0
# 84        19      24  14489.0
# 95        31      37   7799.0
# 104       19      25  17199.0
# 105       17      23  19699.0
# 106       19      25  18399.0
# 118       37      41   5572.0
# 119       24      30   7957.0
# 124       19      24  12764.0
# 125       19      27  22018.0
# 129       17      28  10295.0
# 131       23      31   9895.0
# 132       21      28  11850.0
# 134       21      28  15040.0
# 136       19      26  18150.0
# 138       31      36   5118.0
# 139       26      31   7053.0
# 140       26      31   7603.0
# 150       35      39   5348.0
# 151       31      38   6338.0
# 164       29      34   8238.0
# 166       26      29   9538.0
# 169       24      30   9989.0
# 171       24      30  11549.0
# 178       20      24  16558.0
# 179       19      24  15998.0
# 190       24      29   9980.0
#
# [60 rows x 26 columns]

# %%
df.loc[(df['body']=='hatchback')&(df['doors']=='four')]
# Out:
#      symboling  normalized-losses      make fuel-type aspiration doors  \
# 24           1              148.0     dodge       gas        std  four
# 64           0              115.0     mazda       gas        std  four
# 99           0              106.0    nissan       gas        std  four
# 120          1              154.0  plymouth       gas        std  four
# 152          1               74.0    toyota       gas        std  four
# 157          0               91.0    toyota       gas        std  four
# 159          0               91.0    toyota    diesel        std  four
# 161          0               91.0    toyota       gas        std  four
# 175         -1               65.0    toyota       gas        std  four
# 177         -1               65.0    toyota       gas        std  four
#
#           body drive-wheels engine-location  wheel-base  ...  engine-size  \
# 24   hatchback          fwd           front        93.7  ...           90
# 64   hatchback          fwd           front        98.8  ...          122
# 99   hatchback          fwd           front        97.2  ...          120
# 120  hatchback          fwd           front        93.7  ...           90
# 152  hatchback          fwd           front        95.7  ...           92
# 157  hatchback          fwd           front        95.7  ...           98
# 159  hatchback          fwd           front        95.7  ...          110
# 161  hatchback          fwd           front        95.7  ...           98
# 175  hatchback          fwd           front       102.4  ...          122
# 177  hatchback          fwd           front       102.4  ...          122
#
#      fuel-system  bore  stroke compression-ratio    hp  peak-rpm city-mpg  \
# 24          2bbl  2.97    3.23               9.4  68.0    5500.0       31
# 64          2bbl  3.39    3.39               8.6  84.0    4800.0       26
# 99          2bbl  3.33    3.47               8.5  97.0    5200.0       27
# 120         2bbl  2.97    3.23               9.4  68.0    5500.0       31
# 152         2bbl  3.05    3.03               9.0  62.0    4800.0       31
# 157         2bbl  3.19    3.03               9.0  70.0    4800.0       30
# 159          idi  3.27    3.35              22.5  56.0    4500.0       38
# 161         2bbl  3.19    3.03               9.0  70.0    4800.0       28
# 175         mpfi  3.31    3.54               8.7  92.0    4200.0       27
# 177         mpfi  3.31    3.54               8.7  92.0    4200.0       27
#
#      hw-mpg    price
# 24       38   6229.0
# 64       32  11245.0
# 99       34   8949.0
# 120      38   6229.0
# 152      38   6488.0
# 157      37   7198.0
# 159      47   7788.0
# 161      34   8358.0
# 175      32   9988.0
# 177      32  11248.0
#
# [10 rows x 26 columns]

# %%
df.loc[df['body']=='hardtop']
# Out:
#      symboling  normalized-losses           make fuel-type aspiration doors  \
# 69           0               93.0  mercedes-benz    diesel      turbo   two
# 74           1              122.0  mercedes-benz       gas        std   two
# 98           2              168.0         nissan       gas        std   two
# 126          3              122.0        porsche       gas        std   two
# 127          3              122.0        porsche       gas        std   two
# 167          2              134.0         toyota       gas        std   two
# 168          2              134.0         toyota       gas        std   two
# 170          2              134.0         toyota       gas        std   two
#
#         body drive-wheels engine-location  wheel-base  ...  engine-size  \
# 69   hardtop          rwd           front       106.7  ...          183
# 74   hardtop          rwd           front       112.0  ...          304
# 98   hardtop          fwd           front        95.1  ...           97
# 126  hardtop          rwd            rear        89.5  ...          194
# 127  hardtop          rwd            rear        89.5  ...          194
# 167  hardtop          rwd           front        98.4  ...          146
# 168  hardtop          rwd           front        98.4  ...          146
# 170  hardtop          rwd           front        98.4  ...          146
#
#      fuel-system  bore  stroke compression-ratio     hp  peak-rpm city-mpg  \
# 69           idi  3.58    3.64              21.5  123.0    4350.0       22
# 74          mpfi  3.80    3.35               8.0  184.0    4500.0       14
# 98          2bbl  3.15    3.29               9.4   69.0    5200.0       31
# 126         mpfi  3.74    2.90               9.5  207.0    5900.0       17
# 127         mpfi  3.74    2.90               9.5  207.0    5900.0       17
# 167         mpfi  3.62    3.50               9.3  116.0    4800.0       24
# 168         mpfi  3.62    3.50               9.3  116.0    4800.0       24
# 170         mpfi  3.62    3.50               9.3  116.0    4800.0       24
#
#      hw-mpg    price
# 69       25  28176.0
# 74       16  45400.0
# 98       37   8249.0
# 126      25  32528.0
# 127      25  34028.0
# 167      30   8449.0
# 168      30   9639.0
# 170      30  11199.0
#
# [8 rows x 26 columns]

# %%
df.loc[df['doors']=='nan']
# Out:
#     symboling  normalized-losses   make fuel-type aspiration doors   body  \
# 27          1              148.0  dodge       gas      turbo   nan  sedan
# 63          0              122.0  mazda    diesel        std   nan  sedan
#
#    drive-wheels engine-location  wheel-base  ...  engine-size  fuel-system  \
# 27          fwd           front        93.7  ...           98         mpfi
# 63          fwd           front        98.8  ...          122          idi
#
#     bore  stroke compression-ratio     hp  peak-rpm city-mpg  hw-mpg    price
# 27  3.03    3.39               7.6  102.0    5500.0       24      30   8558.0
# 63  3.39    3.39              22.7   64.0    4650.0       36      42  10795.0
#
# [2 rows x 26 columns]

# %%
#After observing, I come up with the decision tree model to fill in doors attribute (in the report).

# %%
#I take the mode of sedan body.
df.loc[(df['body']=='sedan')].mode()
# Out:
#    symboling  normalized-losses    make fuel-type aspiration doors   body  \
# 0          0              122.0  toyota       gas        std  four  sedan
#
#   drive-wheels engine-location  wheel-base  ...  engine-size  fuel-system  \
# 0          fwd           front        94.5  ...           97         mpfi
#
#    bore  stroke compression-ratio    hp  peak-rpm city-mpg  hw-mpg    price
# 0  3.19     3.4               9.0  68.0    5500.0       31      25  10295.0
#
# [1 rows x 26 columns]

# %%
#Therefore, I fill missing values in doors attribute with "four" value
df['doors']=df['doors'].replace('nan','four')

# %%
#Observing the data frame again
df.head(60)
# Out:
#     symboling  normalized-losses         make fuel-type aspiration doors  \
# 0           3              122.0  alfa-romero       gas        std   two
# 1           3              122.0  alfa-romero       gas        std   two
# 2           1              122.0  alfa-romero       gas        std   two
# 3           2              164.0         audi       gas        std  four
# 4           2              164.0         audi       gas        std  four
# 5           2              122.0         audi       gas        std   two
# 6           1              158.0         audi       gas        std  four
# 7           1              122.0         audi       gas        std  four
# 8           1              158.0         audi       gas      turbo  four
# 9           0              122.0         audi       gas      turbo   two
# 10          2              192.0          bmw       gas        std   two
# 11          0              192.0          bmw       gas        std  four
# 12          0              188.0          bmw       gas        std   two
# 13          0              188.0          bmw       gas        std  four
# 14          1              122.0          bmw       gas        std  four
# 15          0              122.0          bmw       gas        std  four
# 16          0              122.0          bmw       gas        std   two
# 17          0              122.0          bmw       gas        std  four
# 18          2              121.0    chevrolet       gas        std   two
# 19          1               98.0    chevrolet       gas        std   two
# 20          0               81.0    chevrolet       gas        std  four
# 21          1              118.0        dodge       gas        std   two
# 22          1              118.0        dodge       gas        std   two
# 23          1              118.0        dodge       gas      turbo   two
# 24          1              148.0        dodge       gas        std  four
# 25          1              148.0        dodge       gas        std  four
# 26          1              148.0        dodge       gas        std  four
# 27          1              148.0        dodge       gas      turbo  four
# 28         -1              110.0        dodge       gas        std  four
# 29          3              145.0        dodge       gas      turbo   two
# 30          2              137.0        honda       gas        std   two
# 31          2              137.0        honda       gas        std   two
# 32          1              101.0        honda       gas        std   two
# 33          1              101.0        honda       gas        std   two
# 34          1              101.0        honda       gas        std   two
# 35          0              110.0        honda       gas        std  four
# 36          0               78.0        honda       gas        std  four
# 37          0              106.0        honda       gas        std   two
# 38          0              106.0        honda       gas        std   two
# 39          0               85.0        honda       gas        std  four
# 40          0               85.0        honda       gas        std  four
# 41          0               85.0        honda       gas        std  four
# 42          1              107.0        honda       gas        std   two
# 43          0              122.0        isuzu       gas        std  four
# 44          1              122.0        isuzu       gas        std   two
# 45          0              122.0        isuzu       gas        std  four
# 46          2              122.0        isuzu       gas        std   two
# 47          0              145.0       jaguar       gas        std  four
# 48          0              122.0       jaguar       gas        std  four
# 49          0              122.0       jaguar       gas        std   two
# 50          1              104.0        mazda       gas        std   two
# 51          1              104.0        mazda       gas        std   two
# 52          1              104.0        mazda       gas        std   two
# 53          1              113.0        mazda       gas        std  four
# 54          1              113.0        mazda       gas        std  four
# 55          3              150.0        mazda       gas        std   two
# 56          3              150.0        mazda       gas        std   two
# 57          3              150.0        mazda       gas        std   two
# 58          3              150.0        mazda       gas        std   two
# 59          1              129.0        mazda       gas        std   two
#
#            body drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0   convertible          rwd           front        88.6  ...          130
# 1   convertible          rwd           front        88.6  ...          130
# 2     hatchback          rwd           front        94.5  ...          152
# 3         sedan          fwd           front        99.8  ...          109
# 4         sedan          4wd           front        99.4  ...          136
# 5         sedan          fwd           front        99.8  ...          136
# 6         sedan          fwd           front       105.8  ...          136
# 7         wagon          fwd           front       105.8  ...          136
# 8         sedan          fwd           front       105.8  ...          131
# 9     hatchback          4wd           front        99.5  ...          131
# 10        sedan          rwd           front       101.2  ...          108
# 11        sedan          rwd           front       101.2  ...          108
# 12        sedan          rwd           front       101.2  ...          164
# 13        sedan          rwd           front       101.2  ...          164
# 14        sedan          rwd           front       103.5  ...          164
# 15        sedan          rwd           front       103.5  ...          209
# 16        sedan          rwd           front       103.5  ...          209
# 17        sedan          rwd           front       110.0  ...          209
# 18    hatchback          fwd           front        88.4  ...           61
# 19    hatchback          fwd           front        94.5  ...           90
# 20        sedan          fwd           front        94.5  ...           90
# 21    hatchback          fwd           front        93.7  ...           90
# 22    hatchback          fwd           front        93.7  ...           90
# 23    hatchback          fwd           front        93.7  ...           98
# 24    hatchback          fwd           front        93.7  ...           90
# 25        sedan          fwd           front        93.7  ...           90
# 26        sedan          fwd           front        93.7  ...           90
# 27        sedan          fwd           front        93.7  ...           98
# 28        wagon          fwd           front       103.3  ...          122
# 29    hatchback          fwd           front        95.9  ...          156
# 30    hatchback          fwd           front        86.6  ...           92
# 31    hatchback          fwd           front        86.6  ...           92
# 32    hatchback          fwd           front        93.7  ...           79
# 33    hatchback          fwd           front        93.7  ...           92
# 34    hatchback          fwd           front        93.7  ...           92
# 35        sedan          fwd           front        96.5  ...           92
# 36        wagon          fwd           front        96.5  ...           92
# 37    hatchback          fwd           front        96.5  ...          110
# 38    hatchback          fwd           front        96.5  ...          110
# 39        sedan          fwd           front        96.5  ...          110
# 40        sedan          fwd           front        96.5  ...          110
# 41        sedan          fwd           front        96.5  ...          110
# 42        sedan          fwd           front        96.5  ...          110
# 43        sedan          rwd           front        94.3  ...          111
# 44        sedan          fwd           front        94.5  ...           90
# 45        sedan          fwd           front        94.5  ...           90
# 46    hatchback          rwd           front        96.0  ...          119
# 47        sedan          rwd           front       113.0  ...          258
# 48        sedan          rwd           front       113.0  ...          258
# 49        sedan          rwd           front       102.0  ...          326
# 50    hatchback          fwd           front        93.1  ...           91
# 51    hatchback          fwd           front        93.1  ...           91
# 52    hatchback          fwd           front        93.1  ...           91
# 53        sedan          fwd           front        93.1  ...           91
# 54        sedan          fwd           front        93.1  ...           91
# 55    hatchback          rwd           front        95.3  ...           70
# 56    hatchback          rwd           front        95.3  ...           70
# 57    hatchback          rwd           front        95.3  ...           70
# 58    hatchback          rwd           front        95.3  ...           80
# 59    hatchback          fwd           front        98.8  ...          122
#
#     fuel-system      bore    stroke compression-ratio     hp  peak-rpm  \
# 0          mpfi  3.470000  2.680000              9.00  111.0    5000.0
# 1          mpfi  3.470000  2.680000              9.00  111.0    5000.0
# 2          mpfi  2.680000  3.470000              9.00  154.0    5000.0
# 3          mpfi  3.190000  3.400000             10.00  102.0    5500.0
# 4          mpfi  3.190000  3.400000              8.00  115.0    5500.0
# 5          mpfi  3.190000  3.400000              8.50  110.0    5500.0
# 6          mpfi  3.190000  3.400000              8.50  110.0    5500.0
# 7          mpfi  3.190000  3.400000              8.50  110.0    5500.0
# 8          mpfi  3.130000  3.400000              8.30  140.0    5500.0
# 9          mpfi  3.130000  3.400000              7.00  160.0    5500.0
# 10         mpfi  3.500000  2.800000              8.80  101.0    5800.0
# 11         mpfi  3.500000  2.800000              8.80  101.0    5800.0
# 12         mpfi  3.310000  3.190000              9.00  121.0    4250.0
# 13         mpfi  3.310000  3.190000              9.00  121.0    4250.0
# 14         mpfi  3.310000  3.190000              9.00  121.0    4250.0
# 15         mpfi  3.620000  3.390000              8.00  182.0    5400.0
# 16         mpfi  3.620000  3.390000              8.00  182.0    5400.0
# 17         mpfi  3.620000  3.390000              8.00  182.0    5400.0
# 18         2bbl  2.910000  3.030000              9.50   48.0    5100.0
# 19         2bbl  3.030000  3.110000              9.60   70.0    5400.0
# 20         2bbl  3.030000  3.110000              9.60   70.0    5400.0
# 21         2bbl  2.970000  3.230000              9.41   68.0    5500.0
# 22         2bbl  2.970000  3.230000              9.40   68.0    5500.0
# 23         mpfi  3.030000  3.390000              7.60  102.0    5500.0
# 24         2bbl  2.970000  3.230000              9.40   68.0    5500.0
# 25         2bbl  2.970000  3.230000              9.40   68.0    5500.0
# 26         2bbl  2.970000  3.230000              9.40   68.0    5500.0
# 27         mpfi  3.030000  3.390000              7.60  102.0    5500.0
# 28         2bbl  3.340000  3.460000              8.50   88.0    5000.0
# 29          mfi  3.600000  3.900000              7.00  145.0    5000.0
# 30         1bbl  2.910000  3.410000              9.60   58.0    4800.0
# 31         1bbl  2.910000  3.410000              9.20   76.0    6000.0
# 32         1bbl  2.910000  3.070000             10.10   60.0    5500.0
# 33         1bbl  2.910000  3.410000              9.20   76.0    6000.0
# 34         1bbl  2.910000  3.410000              9.20   76.0    6000.0
# 35         1bbl  2.910000  3.410000              9.20   76.0    6000.0
# 36         1bbl  2.920000  3.410000              9.20   76.0    6000.0
# 37         1bbl  3.150000  3.580000              9.00   86.0    5800.0
# 38         1bbl  3.150000  3.580000              9.00   86.0    5800.0
# 39         1bbl  3.150000  3.580000              9.00   86.0    5800.0
# 40         1bbl  3.150000  3.580000              9.00   86.0    5800.0
# 41         mpfi  3.150000  3.580000              9.00  101.0    5800.0
# 42         2bbl  3.150000  3.580000              9.10  100.0    5500.0
# 43         2bbl  3.310000  3.230000              8.50   78.0    4800.0
# 44         2bbl  3.030000  3.110000              9.60   70.0    5400.0
# 45         2bbl  3.030000  3.110000              9.60   70.0    5400.0
# 46         spfi  3.430000  3.230000              9.20   90.0    5000.0
# 47         mpfi  3.630000  4.170000              8.10  176.0    4750.0
# 48         mpfi  3.630000  4.170000              8.10  176.0    4750.0
# 49         mpfi  3.540000  2.760000             11.50  262.0    5000.0
# 50         2bbl  3.030000  3.150000              9.00   68.0    5000.0
# 51         2bbl  3.030000  3.150000              9.00   68.0    5000.0
# 52         2bbl  3.030000  3.150000              9.00   68.0    5000.0
# 53         2bbl  3.030000  3.150000              9.00   68.0    5000.0
# 54         2bbl  3.080000  3.150000              9.00   68.0    5000.0
# 55         4bbl  3.329751  3.255423              9.40  101.0    6000.0
# 56         4bbl  3.329751  3.255423              9.40  101.0    6000.0
# 57         4bbl  3.329751  3.255423              9.40  101.0    6000.0
# 58         mpfi  3.329751  3.255423              9.40  135.0    6000.0
# 59         2bbl  3.390000  3.390000              8.60   84.0    4800.0
#
#    city-mpg  hw-mpg    price
# 0        21      27  13495.0
# 1        21      27  16500.0
# 2        19      26  16500.0
# 3        24      30  13950.0
# 4        18      22  17450.0
# 5        19      25  15250.0
# 6        19      25  17710.0
# 7        19      25  18920.0
# 8        17      20  23875.0
# 9        16      22  10295.0
# 10       23      29  16430.0
# 11       23      29  16925.0
# 12       21      28  20970.0
# 13       21      28  21105.0
# 14       20      25  24565.0
# 15       16      22  30760.0
# 16       16      22  41315.0
# 17       15      20  36880.0
# 18       47      53   5151.0
# 19       38      43   6295.0
# 20       38      43   6575.0
# 21       37      41   5572.0
# 22       31      38   6377.0
# 23       24      30   7957.0
# 24       31      38   6229.0
# 25       31      38   6692.0
# 26       31      38   7609.0
# 27       24      30   8558.0
# 28       24      30   8921.0
# 29       19      24  12964.0
# 30       49      54   6479.0
# 31       31      38   6855.0
# 32       38      42   5399.0
# 33       30      34   6529.0
# 34       30      34   7129.0
# 35       30      34   7295.0
# 36       30      34   7295.0
# 37       27      33   7895.0
# 38       27      33   9095.0
# 39       27      33   8845.0
# 40       27      33  10295.0
# 41       24      28  12945.0
# 42       25      31  10345.0
# 43       24      29   6785.0
# 44       38      43  10295.0
# 45       38      43  10295.0
# 46       24      29  11048.0
# 47       15      19  32250.0
# 48       15      19  35550.0
# 49       13      17  36000.0
# 50       30      31   5195.0
# 51       31      38   6095.0
# 52       31      38   6795.0
# 53       31      38   6695.0
# 54       31      38   7395.0
# 55       17      23  10945.0
# 56       17      23  11845.0
# 57       17      23  13645.0
# 58       16      23  15645.0
# 59       26      32   8845.0
#
# [60 rows x 26 columns]
